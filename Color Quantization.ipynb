# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.image as mpimg

# %%
# .jpg, .img --> numpy-arrays

# %%
image_as_array = mpimg.imread(r"C:\Users\Надежда\Downloads\UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V14\DATA\palm_trees.jpg")

# %%
image_as_array
# Out:
# array([[[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 23,  63,  98],
#         [ 51,  91, 127],
#         [ 50,  90, 126]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 31,  71, 106],
#         [ 48,  88, 124],
#         [ 47,  90, 125]],
#
#        [[ 25,  89, 127],
#         [ 25,  89, 127],
#         [ 25,  89, 127],
#         ...,
#         [ 39,  79, 114],
#         [ 42,  85, 120],
#         [ 44,  88, 123]],
#
#        ...,
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
#         ...,
#         [  9,   9,  11],
#         [  9,   9,  11],
#         [  9,   9,  11]],
#
#        [[  3,   3,   5],
#         [  3,   3,   5],
#         [  3,   3,   5],
#         ...,
#         [  8,   8,  10],
#         [  8,   8,  10],
#         [  8,   8,  10]],
#
#        [[  4,   4,   6],
#         [  4,   4,   6],
#         [  4,   4,   6],
# ...

# %%
image_as_array.shape
# H, W, C 
#C - Color Channels - base colors
# Out:
# (1401, 934, 3)

# %%
#plt.figure(dpi=200)
plt.imshow(image_as_array) # works with numpy arrays only

# %%
# (H, W, C) --> 2D (H x W, C)

# %%
(h, w, c) = image_as_array.shape

# %%
image_as_array2d = image_as_array.reshape(h*w, c)

# %%
image_as_array2d
# Out:
# array([[ 25,  89, 127],
#        [ 25,  89, 127],
#        [ 25,  89, 127],
#        ...,
#        [  9,   9,  11],
#        [ 10,  10,  12],
#        [ 10,  10,  12]], shape=(1308534, 3), dtype=uint8)

# %%
len(image_as_array2d.shape)
# Out:
# 2

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array2d)

# %%
labels
# Out:
# array([5, 5, 5, ..., 0, 0, 0], shape=(1308534,), dtype=int32)

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[  3,   3,   4],
#        [ 67,  62,  62],
#        [137, 144, 144],
#        [191, 154, 110],
#        [219, 136,  47],
#        [ 71, 109, 138]])

# %%
rgb_codes[labels]
# Out:
# array([[ 71, 109, 138],
#        [ 71, 109, 138],
#        [ 71, 109, 138],
#        ...,
#        [  3,   3,   4],
#        [  3,   3,   4],
#        [  3,   3,   4]], shape=(1308534, 3))

# %%
#image_as_array2d

# %%
quantised_image = np.reshape(rgb_codes[labels], (h, w, c))

# %%
plt.imshow(quantised_image)
